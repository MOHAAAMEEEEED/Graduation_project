# %% [markdown]
# <a href="https://colab.research.google.com/github/MOHAAAMEEEEED/Graduation_project/blob/main/audio_%26_keyword_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import subprocess
import whisper
import logging
from typing import Optional, Dict, Union
from pathlib import Path

class WhisperTranscriber:
    """
    A class to handle audio/video transcription using OpenAI's Whisper model.
    Supports multiple input formats and handles conversion to WAV using FFmpeg.
    """

    def __init__(self):
        """
        Initialize the transcriber with the 'base' Whisper model.
        """
        self.setup_logging()
        self.model = whisper.load_model("base")
        self.language = "en"

    def setup_logging(self) -> None:
        """Configure logging for the transcriber."""
        logging.basicConfig(
            level=logging.INFO,         #  Set the logging level to INFO to capture informational messages and above
            format='%(asctime)s - %(levelname)s - %(message)s'
        )
        self.logger = logging.getLogger(__name__)       # Create a logger instance associated with the current module's name, allowing other methods to log messages

    def convert_to_wav(self, input_file: Union[str, Path], output_dir: Optional[str] = None) -> Optional[str]:
        """#
        Convert input audio/video file to WAV format using FFmpeg.

        Args:
            input_file (Union[str, Path]): Path to input audio/video file
            output_dir (Optional[str]): Directory for output WAV file

        Returns:
            Optional[str]: Path to output WAV file if successful, None otherwise
        """
        try:
            input_path = Path(input_file)
            if not input_path.exists():
                self.logger.error(f"Input file not found: {input_file}")
                return None

            # Determine output path
            if output_dir:
                output_path = Path(output_dir) / f"{input_path.stem}.wav"
            else:
                output_path = input_path.with_suffix('.wav')

            # Create output directory if it doesn't exist
            output_path.parent.mkdir(parents=True, exist_ok=True)

            # FFmpeg command for conversion
            command = [
                'ffmpeg',
                '-i', str(input_path),
                '-ar', '16000',  # Sample rate 16kHz
                '-ac', '1',      # Mono audio
                '-c:a', 'pcm_s16le',  # 16-bit PCM encoding
                str(output_path),
                '-y'  # Overwrite output file if exists
            ]

            self.logger.info(f"Converting {input_path} to WAV format")
            result = subprocess.run(
                command,
                stdout=subprocess.PIPE,
                stderr=subprocess.PIPE,
                text=True
            )

            if result.returncode != 0:
                self.logger.error(f"FFmpeg conversion failed: {result.stderr}")
                return None

            self.logger.info("Conversion successful")
            return str(output_path)

        except Exception as e:
            self.logger.error(f"Error during conversion: {str(e)}")
            return None

    def transcribe(self,
                  input_file: Union[str, Path],
                  output_dir: Optional[str] = None,
                  cleanup: bool = True) -> Dict:
        """
        Transcribe audio/video file using Whisper.

        Args:
            input_file (Union[str, Path]): Path to input audio/video file
            output_dir (Optional[str]): Directory for temporary WAV file
            cleanup (bool): Whether to delete temporary WAV file after transcription

        Returns:
            Dict: Transcription result containing text and other metadata
        """
        try:
            # Convert to WAV if input is not already WAV
            input_path = Path(input_file)
            if input_path.suffix.lower() != '.wav':
                self.logger.info("Converting input file to WAV format")
                wav_file = self.convert_to_wav(input_file, output_dir)
                if not wav_file:
                    raise RuntimeError("Failed to convert input file to WAV format")
            else:
                wav_file = str(input_path)

            # Perform transcription
            self.logger.info("Starting transcription")
            result = self.model.transcribe(wav_file, language=self.language)
            self.logger.info("Transcription completed successfully")

            # Cleanup temporary WAV file if requested
            if cleanup and input_path.suffix.lower() != '.wav':
                try:
                    os.remove(wav_file)
                    self.logger.info(f"Cleaned up temporary WAV file: {wav_file}")
                except Exception as e:
                    self.logger.warning(f"Failed to cleanup temporary file: {str(e)}")

            return result

        except Exception as e:
            self.logger.error(f"Transcription failed: {str(e)}")
            raise

# %%
# Initialize transcriber
transcriber = WhisperTranscriber()

input_file = "/content/Small Talk  Everyday English.mp4"
try:
    result = transcriber.transcribe(input_file)

    # Store the transcribed text in a variable
    transcribed_text = result['text']

    # Print the transcribed text
    print(f"Transcription: {transcribed_text}")

    # You can now use transcribed_text for further processing
    # For example, save to a file or use in other functions
except Exception as e:
    print(f"Transcription failed: {e}")
# Out:
# Transcription:  So, what's new Mark? How is your new job going? To be honest, I can't complain. I really love the company that I am working for. My co-workers are all really friendly and helpful. They really help me feel welcome. It's a really energetic and fun atmosphere. My boss is hilarious and he's really flexible. Really? How so? He allows me to come in when I want and make my own hours. I can also leave early if I start early. There is no real dress code either. I can wear jeans and a t-shirt if I want. I can even wear shorts in the summer. Wow. It sounds really cool. I can't stand wearing a suit every day. Which do you prefer? Working late or finishing early? I prefer finishing early. I really enjoy the morning. I love getting up early and going for a run. There is nothing like watching the sunrise while drinking my morning coffee. Really? I am opposite. I love sleeping in. I am most alert in the evenings. I'm a real night owl. Well, you know what they say. The early bird catches the worm. You know, you could be right. Maybe I will try to go to bed a little earlier tonight.

# %% [markdown]
# ## preprocessing

# %%
import nltk
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

import re
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))
for char in string.punctuation:
    print(char,end= " ")
# Out:
# ! " # $ % & ' ( ) * + , - . / : ; < = > ? @ [ \ ] ^ _ ` { | } ~

# %% [markdown]
# #### Using `lemmatization` here in preprocessing as it reduces words to their base , considering the context and the actual meaning. which will be useful for `keyword extraction` as it help maintain the correct semantic meaning, improving the accuracy .

# %%
translated_table = str.maketrans('', '', string.punctuation)
lemmatizer=WordNetLemmatizer()


def preprocess_text(text):
    text = text.lower()
    text = text.translate(translated_table)

    text = re.sub(r'\d+', '', text)       # Remove numbers

    tokens = word_tokenize(text)

    # Remove stopwords and lemmatize
    processed_tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]

    #processed_tokens = [word for word in tokens if word not in stop_words]


    # Join tokens back into a single string
    processed_text = ' '.join(processed_tokens)

    return processed_text

# %%
preprocessed_text = preprocess_text(transcribed_text)
print(f"Preprocessed Text: {preprocessed_text}")
# Out:
# Preprocessed Text: whats new mark new job going honest cant complain really love company working coworkers really friendly helpful really help feel welcome really energetic fun atmosphere bos hilarious he really flexible really allows come want make hour also leave early start early real dress code either wear jean tshirt want even wear short summer wow sound really cool cant stand wearing suit every day prefer working late finishing early prefer finishing early really enjoy morning love getting early going run nothing like watching sunrise drinking morning coffee really opposite love sleeping alert evening im real night owl well know say early bird catch worm know could right maybe try go bed little earlier tonight

# %% [markdown]
# #### extract important keywords from text

# %%
from keybert import KeyBERT
import spacy

# Load spaCy model for POS tagging
nlp = spacy.load("en_core_web_sm")

# Sample preprocessed text, replace this with your actual preprocessed text
text = preprocessed_text
# Initialize KeyBERT model
kw_model = KeyBERT()

# Extract keywords with KeyBERT
raw_keywords = kw_model.extract_keywords(text, keyphrase_ngram_range=(1, 2), stop_words='english', top_n=10)
raw_keywords = [kw[0] for kw in raw_keywords]  # Keep only the keywords without scores

# Filter keywords using spaCy for relevant parts of speech
filtered_keywords = []
for keyword in raw_keywords:
    doc = nlp(keyword)
    # Check if all tokens in the keyword are either NOUN or PROPN
    if all(token.pos_ in {"NOUN", "PROPN"} for token in doc):
        filtered_keywords.append(keyword)

print("Relevant job keywords:", filtered_keywords)
# Out:
# /usr/local/lib/python3.10/dist-packages/spacy/util.py:1740: UserWarning: [W111] Jupyter notebook detected: if using `prefer_gpu()` or `require_gpu()`, include it in the same cell right before `spacy.load()` to ensure that the model is loaded on the correct device. More information: http://spacy.io/usage/v3#jupyter-notebook-gpu
#   warnings.warn(Warnings.W111)
# Relevant job keywords: ['mark new', 'job', 'mark']

# %% [markdown]
# #### Find synonyms of words in text

# %%
from nltk.corpus import wordnet as wn
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np


# Load pre-trained BERT model and tokenizer
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
model = AutoModel.from_pretrained('bert-base-uncased')

def get_embedding(word):
    inputs = tokenizer(word, return_tensors="pt")
    outputs = model(**inputs)
    # Use the [CLS] token embedding for simplicity
    return outputs.last_hidden_state[0][0].detach().numpy()

def cosine_similarity(vec1, vec2):
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

def find_synonyms_with_scores(word):
    word_embedding = get_embedding(word)
    synonyms = set()

    # Get synonyms from WordNet
    for synset in wn.synsets(word):
        for lemma in synset.lemmas():
            synonym = lemma.name().replace('_', ' ')
            if synonym != word:  # Avoid the word itself
                synonyms.add(synonym)

    # Calculate similarity scores
    synonym_scores = {}
    for synonym in synonyms:
        synonym_embedding = get_embedding(synonym)
        similarity_score = cosine_similarity(word_embedding, synonym_embedding)
        synonym_scores[synonym] = similarity_score

    return sorted(synonym_scores.items(), key=lambda x: x[1], reverse=True)

def process_sentence(sentence):
    words = sentence.split()
    results = {}

    for word in words:
        synonyms_with_scores = find_synonyms_with_scores(word)
        results[word] = synonyms_with_scores[:5]  # Get top 5 synonyms based on score

    return results

# Example usage
sentence = preprocessed_text
synonyms_with_accuracy = process_sentence(sentence)

for word, synonyms in synonyms_with_accuracy.items():
    print(f"Word: {word}")
    for synonym, score in synonyms:
        print(f"  Synonym: {synonym}, Similarity Score: {score:.2f}")
# Out:
# Word: whats
# Word: new
#   Synonym: New, Similarity Score: 1.00
#   Synonym: newly, Similarity Score: 0.94
#   Synonym: novel, Similarity Score: 0.94
#   Synonym: fresh, Similarity Score: 0.94
#   Synonym: Modern, Similarity Score: 0.93
# Word: mark
#   Synonym: Mark, Similarity Score: 1.00
#   Synonym: patsy, Similarity Score: 0.98
#   Synonym: commemorate, Similarity Score: 0.98
#   Synonym: marker, Similarity Score: 0.97
#   Synonym: scar, Similarity Score: 0.97
# Word: job
#   Synonym: Job, Similarity Score: 1.00
#   Synonym: task, Similarity Score: 0.96
#   Synonym: problem, Similarity Score: 0.95
#   Synonym: business, Similarity Score: 0.94
#   Synonym: caper, Similarity Score: 0.94
# Word: going
#   Synonym: leaving, Similarity Score: 0.98
#   Synonym: get, Similarity Score: 0.98
#   Synonym: break, Similarity Score: 0.98
#   Synonym: passing, Similarity Score: 0.98
#   Synonym: belong, Similarity Score: 0.97
# Word: honest
#   Synonym: true, Similarity Score: 0.98
#   Synonym: fair, Similarity Score: 0.98
#   Synonym: dependable, Similarity Score: 0.97
#   Synonym: reliable, Similarity Score: 0.96
#   Synonym: good, Similarity Score: 0.96
# Word: cant
#   Synonym: vernacular, Similarity Score: 0.85
#   Synonym: jargon, Similarity Score: 0.84
#   Synonym: pitch, Similarity Score: 0.83
#   Synonym: patois, Similarity Score: 0.82
#   Synonym: lingo, Similarity Score: 0.82
# Word: complain
#   Synonym: plain, Similarity Score: 0.98
#   Synonym: kick, Similarity Score: 0.97
#   Synonym: sound off, Similarity Score: 0.96
#   Synonym: quetch, Similarity Score: 0.94
#   Synonym: kvetch, Similarity Score: 0.86
# Word: really
#   Synonym: truly, Similarity Score: 0.98
#   Synonym: actually, Similarity Score: 0.98
#   Synonym: very, Similarity Score: 0.98
#   Synonym: genuinely, Similarity Score: 0.98
#   Synonym: in truth, Similarity Score: 0.96
# Word: love
#   Synonym: passion, Similarity Score: 0.96
#   Synonym: erotic love, Similarity Score: 0.95
#   Synonym: honey, Similarity Score: 0.95
#   Synonym: bed, Similarity Score: 0.95
#   Synonym: beloved, Similarity Score: 0.95
# Word: company
#   Synonym: companion, Similarity Score: 0.97
#   Synonym: caller, Similarity Score: 0.97
#   Synonym: accompany, Similarity Score: 0.96
#   Synonym: society, Similarity Score: 0.96
#   Synonym: troupe, Similarity Score: 0.95
# Word: working
#   Synonym: mold, Similarity Score: 0.98
#   Synonym: workings, Similarity Score: 0.98
#   Synonym: functional, Similarity Score: 0.98
#   Synonym: operative, Similarity Score: 0.98
#   Synonym: forge, Similarity Score: 0.98
# Word: coworkers
# Word: friendly
#   Synonym: favorable, Similarity Score: 0.93
#   Synonym: well-disposed, Similarity Score: 0.61
# Word: helpful
# Word: help
#   Synonym: supporter, Similarity Score: 0.97
#   Synonym: aid, Similarity Score: 0.97
#   Synonym: facilitate, Similarity Score: 0.97
#   Synonym: serve, Similarity Score: 0.97
#   Synonym: service, Similarity Score: 0.96
# Word: feel
#   Synonym: smell, Similarity Score: 0.96
#   Synonym: find, Similarity Score: 0.96
#   Synonym: look, Similarity Score: 0.95
#   Synonym: feeling, Similarity Score: 0.95
#   Synonym: sense, Similarity Score: 0.95
# Word: welcome
#   Synonym: receive, Similarity Score: 0.93
# Word: energetic
#   Synonym: gumptious, Similarity Score: 0.90
#   Synonym: up-and-coming, Similarity Score: 0.73
#   Synonym: industrious, Similarity Score: 0.63
# Word: fun
#   Synonym: merriment, Similarity Score: 0.89
#   Synonym: playfulness, Similarity Score: 0.89
#   Synonym: play, Similarity Score: 0.88
#   Synonym: sport, Similarity Score: 0.84
# Word: atmosphere
#   Synonym: air, Similarity Score: 0.97
#   Synonym: aura, Similarity Score: 0.97
#   Synonym: standard pressure, Similarity Score: 0.94
#   Synonym: standard atmosphere, Similarity Score: 0.94
#   Synonym: atmospheric state, Similarity Score: 0.93
# Word: bos
#   Synonym: Bos, Similarity Score: 1.00
#   Synonym: genus Bos, Similarity Score: 0.91
# Word: hilarious
#   Synonym: screaming, Similarity Score: 0.88
#   Synonym: uproarious, Similarity Score: 0.80
# Word: he
#   Synonym: He, Similarity Score: 1.00
#   Synonym: helium, Similarity Score: 0.97
#   Synonym: atomic number 2, Similarity Score: 0.90
# Word: flexible
#   Synonym: elastic, Similarity Score: 0.99
#   Synonym: pliant, Similarity Score: 0.95
#   Synonym: flexile, Similarity Score: 0.94
#   Synonym: compromising, Similarity Score: 0.91
#   Synonym: whippy, Similarity Score: 0.90
# Word: allows
#   Synonym: allow, Similarity Score: 0.99
#   Synonym: permit, Similarity Score: 0.98
#   Synonym: tolerate, Similarity Score: 0.98
#   Synonym: appropriate, Similarity Score: 0.98
#   Synonym: admit, Similarity Score: 0.97
# Word: come
#   Synonym: get, Similarity Score: 0.95
#   Synonym: descend, Similarity Score: 0.95
#   Synonym: follow, Similarity Score: 0.95
#   Synonym: hail, Similarity Score: 0.95
#   Synonym: fall, Similarity Score: 0.95
# Word: want
#   Synonym: need, Similarity Score: 0.99
#   Synonym: wish, Similarity Score: 0.98
#   Synonym: desire, Similarity Score: 0.97
#   Synonym: neediness, Similarity Score: 0.96
#   Synonym: require, Similarity Score: 0.96
# Word: make
#   Synonym: get, Similarity Score: 0.98
#   Synonym: give, Similarity Score: 0.98
#   Synonym: reach, Similarity Score: 0.98
#   Synonym: fix, Similarity Score: 0.98
#   Synonym: realise, Similarity Score: 0.98
# Word: hour
#   Synonym: minute, Similarity Score: 0.97
#   Synonym: 60 minutes, Similarity Score: 0.92
#   Synonym: hr, Similarity Score: 0.90
#   Synonym: time of day, Similarity Score: 0.77
# Word: also
#   Synonym: likewise, Similarity Score: 0.98
#   Synonym: besides, Similarity Score: 0.98
#   Synonym: too, Similarity Score: 0.97
#   Synonym: as well, Similarity Score: 0.97
# Word: leave
#   Synonym: forget, Similarity Score: 0.99
#   Synonym: give, Similarity Score: 0.98
#   Synonym: allow, Similarity Score: 0.98
#   Synonym: exit, Similarity Score: 0.98
#   Synonym: allow for, Similarity Score: 0.98
# Word: early
#   Synonym: other, Similarity Score: 0.96
#   Synonym: early on, Similarity Score: 0.96
#   Synonym: ahead of time, Similarity Score: 0.95
#   Synonym: too soon, Similarity Score: 0.94
#   Synonym: betimes, Similarity Score: 0.93
# Word: start
#   Synonym: starting, Similarity Score: 0.96
#   Synonym: beginning, Similarity Score: 0.95
#   Synonym: head start, Similarity Score: 0.95
#   Synonym: begin, Similarity Score: 0.95
#   Synonym: jump, Similarity Score: 0.95
# Word: real
#   Synonym: actual, Similarity Score: 0.96
#   Synonym: tangible, Similarity Score: 0.96
#   Synonym: substantial, Similarity Score: 0.95
#   Synonym: genuine, Similarity Score: 0.95
#   Synonym: really, Similarity Score: 0.95
# Word: dress
#   Synonym: groom, Similarity Score: 0.98
#   Synonym: attire, Similarity Score: 0.98
#   Synonym: clip, Similarity Score: 0.97
#   Synonym: set, Similarity Score: 0.97
#   Synonym: trim, Similarity Score: 0.97
# Word: code
#   Synonym: cipher, Similarity Score: 0.98
#   Synonym: encipher, Similarity Score: 0.97
#   Synonym: computer code, Similarity Score: 0.96
#   Synonym: cypher, Similarity Score: 0.96
#   Synonym: codification, Similarity Score: 0.88
# Word: either
# Word: wear
#   Synonym: wearing, Similarity Score: 0.98
#   Synonym: bear, Similarity Score: 0.97
#   Synonym: break, Similarity Score: 0.97
#   Synonym: get into, Similarity Score: 0.97
#   Synonym: don, Similarity Score: 0.96
# Word: jean
#   Synonym: denim, Similarity Score: 0.96
#   Synonym: blue jean, Similarity Score: 0.95
#   Synonym: dungaree, Similarity Score: 0.87
# Word: tshirt
# Word: even
#   Synonym: yet, Similarity Score: 0.99
#   Synonym: even out, Similarity Score: 0.98
#   Synonym: eve, Similarity Score: 0.98
#   Synonym: flush, Similarity Score: 0.97
#   Synonym: still, Similarity Score: 0.97
# Word: short
#   Synonym: inadequate, Similarity Score: 0.95
#   Synonym: little, Similarity Score: 0.94
#   Synonym: poor, Similarity Score: 0.94
#   Synonym: scant, Similarity Score: 0.94
#   Synonym: light, Similarity Score: 0.94
# Word: summer
#   Synonym: summertime, Similarity Score: 0.97
# Word: wow
#   Synonym: riot, Similarity Score: 0.94
#   Synonym: scream, Similarity Score: 0.92
#   Synonym: sidesplitter, Similarity Score: 0.90
#   Synonym: belly laugh, Similarity Score: 0.89
#   Synonym: howler, Similarity Score: 0.89
# Word: sound
#   Synonym: voice, Similarity Score: 0.97
#   Synonym: fathom, Similarity Score: 0.97
#   Synonym: phone, Similarity Score: 0.96
#   Synonym: profound, Similarity Score: 0.96
#   Synonym: reasoned, Similarity Score: 0.96
# Word: cool
#   Synonym: chill, Similarity Score: 0.98
#   Synonym: cool down, Similarity Score: 0.96
#   Synonym: assuredness, Similarity Score: 0.96
#   Synonym: nerveless, Similarity Score: 0.95
#   Synonym: cool off, Similarity Score: 0.94
# Word: stand
#   Synonym: suffer, Similarity Score: 0.94
#   Synonym: endure, Similarity Score: 0.94
#   Synonym: stick out, Similarity Score: 0.94
#   Synonym: place upright, Similarity Score: 0.94
#   Synonym: resist, Similarity Score: 0.93
# Word: wearing
#   Synonym: fatigue, Similarity Score: 0.98
#   Synonym: tire, Similarity Score: 0.98
#   Synonym: wear, Similarity Score: 0.98
#   Synonym: bear, Similarity Score: 0.97
#   Synonym: break, Similarity Score: 0.97
# Word: suit
#   Synonym: accommodate, Similarity Score: 0.97
#   Synonym: fit, Similarity Score: 0.97
#   Synonym: case, Similarity Score: 0.97
#   Synonym: befit, Similarity Score: 0.96
#   Synonym: lawsuit, Similarity Score: 0.96
# Word: every
# Word: day
#   Synonym: Day, Similarity Score: 1.00
#   Synonym: daylight, Similarity Score: 0.96
#   Synonym: sidereal day, Similarity Score: 0.96
#   Synonym: solar day, Similarity Score: 0.95
#   Synonym: Clarence Day, Similarity Score: 0.93
# Word: prefer
#   Synonym: favor, Similarity Score: 0.99
#   Synonym: favour, Similarity Score: 0.98
#   Synonym: choose, Similarity Score: 0.96
#   Synonym: opt, Similarity Score: 0.96
# Word: late
#   Synonym: of late, Similarity Score: 0.97
#   Synonym: lately, Similarity Score: 0.97
#   Synonym: recently, Similarity Score: 0.96
#   Synonym: later, Similarity Score: 0.96
#   Synonym: deep, Similarity Score: 0.95
# Word: finishing
#   Synonym: finish, Similarity Score: 0.97
#   Synonym: stop, Similarity Score: 0.96
#   Synonym: coating, Similarity Score: 0.96
#   Synonym: complete, Similarity Score: 0.95
#   Synonym: cease, Similarity Score: 0.93
# Word: enjoy
#   Synonym: relish, Similarity Score: 0.98
#   Synonym: bask, Similarity Score: 0.98
#   Synonym: delight, Similarity Score: 0.97
#   Synonym: love, Similarity Score: 0.94
#   Synonym: revel, Similarity Score: 0.93
# Word: morning
#   Synonym: sunrise, Similarity Score: 0.97
#   Synonym: dawn, Similarity Score: 0.97
#   Synonym: morning time, Similarity Score: 0.97
#   Synonym: sunup, Similarity Score: 0.97
#   Synonym: forenoon, Similarity Score: 0.96
# Word: getting
#   Synonym: get, Similarity Score: 0.99
#   Synonym: puzzle, Similarity Score: 0.98
#   Synonym: catch, Similarity Score: 0.98
#   Synonym: stick, Similarity Score: 0.98
#   Synonym: make, Similarity Score: 0.97
# Word: run
#   Synonym: go, Similarity Score: 0.95
#   Synonym: unravel, Similarity Score: 0.94
#   Synonym: bleed, Similarity Score: 0.94
#   Synonym: turn tail, Similarity Score: 0.93
#   Synonym: feed, Similarity Score: 0.93
# Word: nothing
#   Synonym: nix, Similarity Score: 0.95
#   Synonym: null, Similarity Score: 0.95
#   Synonym: zip, Similarity Score: 0.95
#   Synonym: naught, Similarity Score: 0.94
#   Synonym: cipher, Similarity Score: 0.94
# Word: like
#   Synonym: wish, Similarity Score: 0.98
#   Synonym: comparable, Similarity Score: 0.98
#   Synonym: the like, Similarity Score: 0.98
#   Synonym: alike, Similarity Score: 0.98
#   Synonym: corresponding, Similarity Score: 0.97
# Word: watching
#   Synonym: watch, Similarity Score: 0.95
#   Synonym: look on, Similarity Score: 0.92
#   Synonym: follow, Similarity Score: 0.91
#   Synonym: take in, Similarity Score: 0.91
#   Synonym: check, Similarity Score: 0.91
# Word: sunrise
#   Synonym: dawn, Similarity Score: 0.99
#   Synonym: sunup, Similarity Score: 0.98
#   Synonym: aurora, Similarity Score: 0.98
#   Synonym: morning, Similarity Score: 0.97
#   Synonym: dayspring, Similarity Score: 0.97
# Word: drinking
#   Synonym: drink, Similarity Score: 0.98
#   Synonym: wassail, Similarity Score: 0.98
#   Synonym: pledge, Similarity Score: 0.98
#   Synonym: salute, Similarity Score: 0.98
#   Synonym: fuddle, Similarity Score: 0.97
# Word: coffee
#   Synonym: chocolate, Similarity Score: 0.98
#   Synonym: coffee bean, Similarity Score: 0.98
#   Synonym: coffee tree, Similarity Score: 0.96
#   Synonym: java, Similarity Score: 0.94
#   Synonym: coffee berry, Similarity Score: 0.93
# Word: opposite
#   Synonym: contrary, Similarity Score: 0.98
#   Synonym: opposite word, Similarity Score: 0.98
#   Synonym: paired, Similarity Score: 0.97
#   Synonym: polar, Similarity Score: 0.96
#   Synonym: reverse, Similarity Score: 0.96
# Word: sleeping
#   Synonym: sleep, Similarity Score: 0.99
#   Synonym: slumber, Similarity Score: 0.96
#   Synonym: quiescence, Similarity Score: 0.95
#   Synonym: dormant, Similarity Score: 0.95
#   Synonym: dormancy, Similarity Score: 0.94
# Word: alert
#   Synonym: brisk, Similarity Score: 0.97
#   Synonym: alarm, Similarity Score: 0.96
#   Synonym: lively, Similarity Score: 0.96
#   Synonym: rattling, Similarity Score: 0.96
#   Synonym: alarum, Similarity Score: 0.96
# Word: evening
#   Synonym: eve, Similarity Score: 0.97
#   Synonym: flush, Similarity Score: 0.96
#   Synonym: level, Similarity Score: 0.96
#   Synonym: even, Similarity Score: 0.96
#   Synonym: even out, Similarity Score: 0.96
# Word: im
# Word: night
#   Synonym: Night, Similarity Score: 1.00
#   Synonym: dark, Similarity Score: 0.97
#   Synonym: nighttime, Similarity Score: 0.97
#   Synonym: Nox, Similarity Score: 0.94
# Word: owl
#   Synonym: hooter, Similarity Score: 0.93
#   Synonym: bird of night, Similarity Score: 0.85
#   Synonym: bird of Minerva, Similarity Score: 0.82
# Word: well
#   Synonym: easily, Similarity Score: 0.97
#   Synonym: intimately, Similarity Score: 0.97
#   Synonym: good, Similarity Score: 0.97
#   Synonym: comfortably, Similarity Score: 0.96
#   Synonym: substantially, Similarity Score: 0.96
# Word: know
#   Synonym: recognize, Similarity Score: 0.98
#   Synonym: acknowledge, Similarity Score: 0.97
#   Synonym: recognise, Similarity Score: 0.95
#   Synonym: bang, Similarity Score: 0.95
#   Synonym: get it on, Similarity Score: 0.94
# Word: say
#   Synonym: tell, Similarity Score: 0.98
#   Synonym: read, Similarity Score: 0.98
#   Synonym: enjoin, Similarity Score: 0.97
#   Synonym: sound out, Similarity Score: 0.97
#   Synonym: order, Similarity Score: 0.96
# Word: bird
#   Synonym: doll, Similarity Score: 0.96
#   Synonym: shuttlecock, Similarity Score: 0.96
#   Synonym: chick, Similarity Score: 0.96
#   Synonym: shuttle, Similarity Score: 0.96
#   Synonym: hiss, Similarity Score: 0.96
# Word: catch
#   Synonym: trance, Similarity Score: 0.99
#   Synonym: hitch, Similarity Score: 0.99
#   Synonym: get, Similarity Score: 0.99
#   Synonym: see, Similarity Score: 0.98
#   Synonym: collar, Similarity Score: 0.98
# Word: worm
#   Synonym: twist, Similarity Score: 0.99
#   Synonym: louse, Similarity Score: 0.98
#   Synonym: insect, Similarity Score: 0.95
#   Synonym: squirm, Similarity Score: 0.95
#   Synonym: writhe, Similarity Score: 0.93
# Word: could
# Word: right
#   Synonym: flop, Similarity Score: 0.97
#   Synonym: proper, Similarity Score: 0.97
#   Synonym: right on, Similarity Score: 0.97
#   Synonym: properly, Similarity Score: 0.97
#   Synonym: correctly, Similarity Score: 0.97
# Word: maybe
#   Synonym: perhaps, Similarity Score: 0.99
#   Synonym: possibly, Similarity Score: 0.97
#   Synonym: mayhap, Similarity Score: 0.92
#   Synonym: peradventure, Similarity Score: 0.92
#   Synonym: perchance, Similarity Score: 0.91
# Word: try
#   Synonym: effort, Similarity Score: 0.97
#   Synonym: try on, Similarity Score: 0.97
#   Synonym: stress, Similarity Score: 0.97
#   Synonym: attempt, Similarity Score: 0.96
#   Synonym: test, Similarity Score: 0.96
# Word: go
#   Synonym: get going, Similarity Score: 0.97
#   Synonym: belong, Similarity Score: 0.97
#   Synonym: spell, Similarity Score: 0.96
#   Synonym: move, Similarity Score: 0.96
#   Synonym: get, Similarity Score: 0.96
# Word: bed
#   Synonym: screw, Similarity Score: 0.95
#   Synonym: love, Similarity Score: 0.95
#   Synonym: bang, Similarity Score: 0.95
#   Synonym: fuck, Similarity Score: 0.95
#   Synonym: layer, Similarity Score: 0.94
# Word: little
#   Synonym: slight, Similarity Score: 0.98
#   Synonym: petty, Similarity Score: 0.97
#   Synonym: minuscule, Similarity Score: 0.96
#   Synonym: footling, Similarity Score: 0.96
#   Synonym: niggling, Similarity Score: 0.95
# Word: earlier
#   Synonym: originally, Similarity Score: 0.98
#   Synonym: early, Similarity Score: 0.98
#   Synonym: other, Similarity Score: 0.98
#   Synonym: earliest, Similarity Score: 0.98
#   Synonym: before, Similarity Score: 0.97
# Word: tonight
#   Synonym: this evening, Similarity Score: 0.95
#   Synonym: this night, Similarity Score: 0.95

# %%
from nltk.corpus import wordnet as wn
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np

# Load pre-trained BERT model and tokenizer
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
model = AutoModel.from_pretrained('bert-base-uncased')

def get_embedding(words):
    inputs = tokenizer(words, return_tensors="pt", padding=True, truncation=True)
    outputs = model(**inputs)
    # Use the [CLS] token embedding for simplicity
    return outputs.last_hidden_state[:, 0, :].detach().numpy()

def cosine_similarity(vec1, vec2):
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

def find_synonyms_with_scores(word):
    synonyms = set()

    # Get synonyms from WordNet
    for synset in wn.synsets(word):
        for lemma in synset.lemmas():
            synonym = lemma.name().replace('_', ' ')
            if synonym != word:  # Avoid the word itself
                synonyms.add(synonym)

    if not synonyms:
        return []

    # Get embeddings for the target word and its synonyms
    word_embedding = get_embedding([word])[0]
    synonym_embeddings = get_embedding(list(synonyms))

    # Calculate similarity scores
    synonym_scores = {}
    for synonym, synonym_embedding in zip(synonyms, synonym_embeddings):
        similarity_score = cosine_similarity(word_embedding, synonym_embedding)
        synonym_scores[synonym] = similarity_score

    return sorted(synonym_scores.items(), key=lambda x: x[1], reverse=True)

def process_sentence(sentence):
    words = sentence.split()
    results = {}

    for word in words:
        synonyms_with_scores = find_synonyms_with_scores(word)
        results[word] = synonyms_with_scores[:5]  # Get top 5 synonyms based on score

    return results

# Example usage
sentence = preprocessed_text
synonyms_with_accuracy = process_sentence(sentence)

for word, synonyms in synonyms_with_accuracy.items():
    print(f"Word: {word}")
    for synonym, score in synonyms:
        print(f"  Synonym: {synonym}, Similarity Score: {score:.2f}")
# Out:
# Word: whats
# Word: new
#   Synonym: New, Similarity Score: 1.00
#   Synonym: newly, Similarity Score: 0.94
#   Synonym: novel, Similarity Score: 0.94
#   Synonym: fresh, Similarity Score: 0.94
#   Synonym: Modern, Similarity Score: 0.93
# Word: mark
#   Synonym: Mark, Similarity Score: 1.00
#   Synonym: patsy, Similarity Score: 0.98
#   Synonym: commemorate, Similarity Score: 0.98
#   Synonym: marker, Similarity Score: 0.97
#   Synonym: scar, Similarity Score: 0.97
# Word: job
#   Synonym: Job, Similarity Score: 1.00
#   Synonym: task, Similarity Score: 0.96
#   Synonym: problem, Similarity Score: 0.95
#   Synonym: business, Similarity Score: 0.94
#   Synonym: caper, Similarity Score: 0.94
# Word: going
#   Synonym: leaving, Similarity Score: 0.98
#   Synonym: get, Similarity Score: 0.98
#   Synonym: break, Similarity Score: 0.98
#   Synonym: passing, Similarity Score: 0.98
#   Synonym: belong, Similarity Score: 0.97
# Word: honest
#   Synonym: true, Similarity Score: 0.98
#   Synonym: fair, Similarity Score: 0.98
#   Synonym: dependable, Similarity Score: 0.97
#   Synonym: reliable, Similarity Score: 0.96
#   Synonym: good, Similarity Score: 0.96
# Word: cant
#   Synonym: vernacular, Similarity Score: 0.85
#   Synonym: jargon, Similarity Score: 0.84
#   Synonym: pitch, Similarity Score: 0.83
#   Synonym: patois, Similarity Score: 0.82
#   Synonym: lingo, Similarity Score: 0.82
# Word: complain
#   Synonym: plain, Similarity Score: 0.98
#   Synonym: kick, Similarity Score: 0.97
#   Synonym: sound off, Similarity Score: 0.96
#   Synonym: quetch, Similarity Score: 0.94
#   Synonym: kvetch, Similarity Score: 0.86
# Word: really
#   Synonym: truly, Similarity Score: 0.98
#   Synonym: actually, Similarity Score: 0.98
#   Synonym: very, Similarity Score: 0.98
#   Synonym: genuinely, Similarity Score: 0.98
#   Synonym: in truth, Similarity Score: 0.96
# Word: love
#   Synonym: passion, Similarity Score: 0.96
#   Synonym: erotic love, Similarity Score: 0.95
#   Synonym: honey, Similarity Score: 0.95
#   Synonym: bed, Similarity Score: 0.95
#   Synonym: beloved, Similarity Score: 0.95
# Word: company
#   Synonym: companion, Similarity Score: 0.97
#   Synonym: caller, Similarity Score: 0.97
#   Synonym: accompany, Similarity Score: 0.96
#   Synonym: society, Similarity Score: 0.96
#   Synonym: troupe, Similarity Score: 0.95
# Word: working
#   Synonym: mold, Similarity Score: 0.98
#   Synonym: workings, Similarity Score: 0.98
#   Synonym: functional, Similarity Score: 0.98
#   Synonym: operative, Similarity Score: 0.98
#   Synonym: forge, Similarity Score: 0.98
# Word: coworkers
# Word: friendly
#   Synonym: favorable, Similarity Score: 0.93
#   Synonym: well-disposed, Similarity Score: 0.61
# Word: helpful
# Word: help
#   Synonym: supporter, Similarity Score: 0.97
#   Synonym: aid, Similarity Score: 0.97
#   Synonym: facilitate, Similarity Score: 0.97
#   Synonym: serve, Similarity Score: 0.97
#   Synonym: service, Similarity Score: 0.96
# Word: feel
#   Synonym: smell, Similarity Score: 0.96
#   Synonym: find, Similarity Score: 0.96
#   Synonym: look, Similarity Score: 0.95
#   Synonym: feeling, Similarity Score: 0.95
#   Synonym: sense, Similarity Score: 0.95
# Word: welcome
#   Synonym: receive, Similarity Score: 0.93
# Word: energetic
#   Synonym: gumptious, Similarity Score: 0.90
#   Synonym: up-and-coming, Similarity Score: 0.73
#   Synonym: industrious, Similarity Score: 0.63
# Word: fun
#   Synonym: merriment, Similarity Score: 0.89
#   Synonym: playfulness, Similarity Score: 0.89
#   Synonym: play, Similarity Score: 0.88
#   Synonym: sport, Similarity Score: 0.84
# Word: atmosphere
#   Synonym: air, Similarity Score: 0.97
#   Synonym: aura, Similarity Score: 0.97
#   Synonym: standard pressure, Similarity Score: 0.94
#   Synonym: standard atmosphere, Similarity Score: 0.94
#   Synonym: atmospheric state, Similarity Score: 0.93
# Word: bos
#   Synonym: Bos, Similarity Score: 1.00
#   Synonym: genus Bos, Similarity Score: 0.91
# Word: hilarious
#   Synonym: screaming, Similarity Score: 0.88
#   Synonym: uproarious, Similarity Score: 0.80
# Word: he
#   Synonym: He, Similarity Score: 1.00
#   Synonym: helium, Similarity Score: 0.97
#   Synonym: atomic number 2, Similarity Score: 0.90
# Word: flexible
#   Synonym: elastic, Similarity Score: 0.99
#   Synonym: pliant, Similarity Score: 0.95
#   Synonym: flexile, Similarity Score: 0.94
#   Synonym: compromising, Similarity Score: 0.91
#   Synonym: whippy, Similarity Score: 0.90
# Word: allows
#   Synonym: allow, Similarity Score: 0.99
#   Synonym: permit, Similarity Score: 0.98
#   Synonym: tolerate, Similarity Score: 0.98
#   Synonym: appropriate, Similarity Score: 0.98
#   Synonym: admit, Similarity Score: 0.97
# Word: come
#   Synonym: get, Similarity Score: 0.95
#   Synonym: descend, Similarity Score: 0.95
#   Synonym: follow, Similarity Score: 0.95
#   Synonym: hail, Similarity Score: 0.95
#   Synonym: fall, Similarity Score: 0.95
# Word: want
#   Synonym: need, Similarity Score: 0.99
#   Synonym: wish, Similarity Score: 0.98
#   Synonym: desire, Similarity Score: 0.97
#   Synonym: neediness, Similarity Score: 0.96
#   Synonym: require, Similarity Score: 0.96
# Word: make
#   Synonym: get, Similarity Score: 0.98
#   Synonym: give, Similarity Score: 0.98
#   Synonym: reach, Similarity Score: 0.98
#   Synonym: fix, Similarity Score: 0.98
#   Synonym: realise, Similarity Score: 0.98
# Word: hour
#   Synonym: minute, Similarity Score: 0.97
#   Synonym: 60 minutes, Similarity Score: 0.92
#   Synonym: hr, Similarity Score: 0.90
#   Synonym: time of day, Similarity Score: 0.77
# Word: also
#   Synonym: likewise, Similarity Score: 0.98
#   Synonym: besides, Similarity Score: 0.98
#   Synonym: too, Similarity Score: 0.97
#   Synonym: as well, Similarity Score: 0.97
# Word: leave
#   Synonym: forget, Similarity Score: 0.99
#   Synonym: give, Similarity Score: 0.98
#   Synonym: allow, Similarity Score: 0.98
#   Synonym: exit, Similarity Score: 0.98
#   Synonym: allow for, Similarity Score: 0.98
# Word: early
#   Synonym: other, Similarity Score: 0.96
#   Synonym: early on, Similarity Score: 0.96
#   Synonym: ahead of time, Similarity Score: 0.95
#   Synonym: too soon, Similarity Score: 0.94
#   Synonym: betimes, Similarity Score: 0.93
# Word: start
#   Synonym: starting, Similarity Score: 0.96
#   Synonym: beginning, Similarity Score: 0.95
#   Synonym: head start, Similarity Score: 0.95
#   Synonym: begin, Similarity Score: 0.95
#   Synonym: jump, Similarity Score: 0.95
# Word: real
#   Synonym: actual, Similarity Score: 0.96
#   Synonym: tangible, Similarity Score: 0.96
#   Synonym: substantial, Similarity Score: 0.95
#   Synonym: genuine, Similarity Score: 0.95
#   Synonym: really, Similarity Score: 0.95
# Word: dress
#   Synonym: groom, Similarity Score: 0.98
#   Synonym: attire, Similarity Score: 0.98
#   Synonym: clip, Similarity Score: 0.97
#   Synonym: set, Similarity Score: 0.97
#   Synonym: trim, Similarity Score: 0.97
# Word: code
#   Synonym: cipher, Similarity Score: 0.98
#   Synonym: encipher, Similarity Score: 0.97
#   Synonym: computer code, Similarity Score: 0.96
#   Synonym: cypher, Similarity Score: 0.96
#   Synonym: codification, Similarity Score: 0.88
# Word: either
# Word: wear
#   Synonym: wearing, Similarity Score: 0.98
#   Synonym: bear, Similarity Score: 0.97
#   Synonym: break, Similarity Score: 0.97
#   Synonym: get into, Similarity Score: 0.97
#   Synonym: don, Similarity Score: 0.96
# Word: jean
#   Synonym: denim, Similarity Score: 0.96
#   Synonym: blue jean, Similarity Score: 0.95
#   Synonym: dungaree, Similarity Score: 0.87
# Word: tshirt
# Word: even
#   Synonym: yet, Similarity Score: 0.99
#   Synonym: even out, Similarity Score: 0.98
#   Synonym: eve, Similarity Score: 0.98
#   Synonym: flush, Similarity Score: 0.97
#   Synonym: still, Similarity Score: 0.97
# Word: short
#   Synonym: inadequate, Similarity Score: 0.95
#   Synonym: little, Similarity Score: 0.94
#   Synonym: poor, Similarity Score: 0.94
#   Synonym: scant, Similarity Score: 0.94
#   Synonym: light, Similarity Score: 0.94
# Word: summer
#   Synonym: summertime, Similarity Score: 0.97
# Word: wow
#   Synonym: riot, Similarity Score: 0.94
#   Synonym: scream, Similarity Score: 0.92
#   Synonym: sidesplitter, Similarity Score: 0.90
#   Synonym: belly laugh, Similarity Score: 0.89
#   Synonym: howler, Similarity Score: 0.89
# Word: sound
#   Synonym: voice, Similarity Score: 0.97
#   Synonym: fathom, Similarity Score: 0.97
#   Synonym: phone, Similarity Score: 0.96
#   Synonym: profound, Similarity Score: 0.96
#   Synonym: reasoned, Similarity Score: 0.96
# Word: cool
#   Synonym: chill, Similarity Score: 0.98
#   Synonym: cool down, Similarity Score: 0.96
#   Synonym: assuredness, Similarity Score: 0.96
#   Synonym: nerveless, Similarity Score: 0.95
#   Synonym: cool off, Similarity Score: 0.94
# Word: stand
#   Synonym: suffer, Similarity Score: 0.94
#   Synonym: endure, Similarity Score: 0.94
#   Synonym: stick out, Similarity Score: 0.94
#   Synonym: place upright, Similarity Score: 0.94
#   Synonym: resist, Similarity Score: 0.93
# Word: wearing
#   Synonym: fatigue, Similarity Score: 0.98
#   Synonym: tire, Similarity Score: 0.98
#   Synonym: wear, Similarity Score: 0.98
#   Synonym: bear, Similarity Score: 0.97
#   Synonym: break, Similarity Score: 0.97
# Word: suit
#   Synonym: accommodate, Similarity Score: 0.97
#   Synonym: fit, Similarity Score: 0.97
#   Synonym: case, Similarity Score: 0.97
#   Synonym: befit, Similarity Score: 0.96
#   Synonym: lawsuit, Similarity Score: 0.96
# Word: every
# Word: day
#   Synonym: Day, Similarity Score: 1.00
#   Synonym: daylight, Similarity Score: 0.96
#   Synonym: sidereal day, Similarity Score: 0.96
#   Synonym: solar day, Similarity Score: 0.95
#   Synonym: Clarence Day, Similarity Score: 0.93
# Word: prefer
#   Synonym: favor, Similarity Score: 0.99
#   Synonym: favour, Similarity Score: 0.98
#   Synonym: choose, Similarity Score: 0.96
#   Synonym: opt, Similarity Score: 0.96
# Word: late
#   Synonym: of late, Similarity Score: 0.97
#   Synonym: lately, Similarity Score: 0.97
#   Synonym: recently, Similarity Score: 0.96
#   Synonym: later, Similarity Score: 0.96
#   Synonym: deep, Similarity Score: 0.95
# Word: finishing
#   Synonym: finish, Similarity Score: 0.97
#   Synonym: stop, Similarity Score: 0.96
#   Synonym: coating, Similarity Score: 0.96
#   Synonym: complete, Similarity Score: 0.95
#   Synonym: cease, Similarity Score: 0.93
# Word: enjoy
#   Synonym: relish, Similarity Score: 0.98
#   Synonym: bask, Similarity Score: 0.98
#   Synonym: delight, Similarity Score: 0.97
#   Synonym: love, Similarity Score: 0.94
#   Synonym: revel, Similarity Score: 0.93
# Word: morning
#   Synonym: sunrise, Similarity Score: 0.97
#   Synonym: dawn, Similarity Score: 0.97
#   Synonym: morning time, Similarity Score: 0.97
#   Synonym: sunup, Similarity Score: 0.97
#   Synonym: forenoon, Similarity Score: 0.96
# Word: getting
#   Synonym: get, Similarity Score: 0.99
#   Synonym: puzzle, Similarity Score: 0.98
#   Synonym: catch, Similarity Score: 0.98
#   Synonym: stick, Similarity Score: 0.98
#   Synonym: make, Similarity Score: 0.97
# Word: run
#   Synonym: go, Similarity Score: 0.95
#   Synonym: unravel, Similarity Score: 0.94
#   Synonym: bleed, Similarity Score: 0.94
#   Synonym: turn tail, Similarity Score: 0.93
#   Synonym: feed, Similarity Score: 0.93
# Word: nothing
#   Synonym: nix, Similarity Score: 0.95
#   Synonym: null, Similarity Score: 0.95
#   Synonym: zip, Similarity Score: 0.95
#   Synonym: naught, Similarity Score: 0.94
#   Synonym: cipher, Similarity Score: 0.94
# Word: like
#   Synonym: wish, Similarity Score: 0.98
#   Synonym: comparable, Similarity Score: 0.98
#   Synonym: the like, Similarity Score: 0.98
#   Synonym: alike, Similarity Score: 0.98
#   Synonym: corresponding, Similarity Score: 0.97
# Word: watching
#   Synonym: watch, Similarity Score: 0.95
#   Synonym: look on, Similarity Score: 0.92
#   Synonym: follow, Similarity Score: 0.91
#   Synonym: take in, Similarity Score: 0.91
#   Synonym: check, Similarity Score: 0.91
# Word: sunrise
#   Synonym: dawn, Similarity Score: 0.99
#   Synonym: sunup, Similarity Score: 0.98
#   Synonym: aurora, Similarity Score: 0.98
#   Synonym: morning, Similarity Score: 0.97
#   Synonym: dayspring, Similarity Score: 0.97
# Word: drinking
#   Synonym: drink, Similarity Score: 0.98
#   Synonym: wassail, Similarity Score: 0.98
#   Synonym: pledge, Similarity Score: 0.98
#   Synonym: salute, Similarity Score: 0.98
#   Synonym: fuddle, Similarity Score: 0.97
# Word: coffee
#   Synonym: chocolate, Similarity Score: 0.98
#   Synonym: coffee bean, Similarity Score: 0.98
#   Synonym: coffee tree, Similarity Score: 0.96
#   Synonym: java, Similarity Score: 0.94
#   Synonym: coffee berry, Similarity Score: 0.93
# Word: opposite
#   Synonym: contrary, Similarity Score: 0.98
#   Synonym: opposite word, Similarity Score: 0.98
#   Synonym: paired, Similarity Score: 0.97
#   Synonym: polar, Similarity Score: 0.96
#   Synonym: reverse, Similarity Score: 0.96
# Word: sleeping
#   Synonym: sleep, Similarity Score: 0.99
#   Synonym: slumber, Similarity Score: 0.96
#   Synonym: quiescence, Similarity Score: 0.95
#   Synonym: dormant, Similarity Score: 0.95
#   Synonym: dormancy, Similarity Score: 0.94
# Word: alert
#   Synonym: brisk, Similarity Score: 0.97
#   Synonym: alarm, Similarity Score: 0.96
#   Synonym: lively, Similarity Score: 0.96
#   Synonym: rattling, Similarity Score: 0.96
#   Synonym: alarum, Similarity Score: 0.96
# Word: evening
#   Synonym: eve, Similarity Score: 0.97
#   Synonym: flush, Similarity Score: 0.96
#   Synonym: level, Similarity Score: 0.96
#   Synonym: even, Similarity Score: 0.96
#   Synonym: even out, Similarity Score: 0.96
# Word: im
# Word: night
#   Synonym: Night, Similarity Score: 1.00
#   Synonym: dark, Similarity Score: 0.97
#   Synonym: nighttime, Similarity Score: 0.97
#   Synonym: Nox, Similarity Score: 0.94
# Word: owl
#   Synonym: hooter, Similarity Score: 0.93
#   Synonym: bird of night, Similarity Score: 0.85
#   Synonym: bird of Minerva, Similarity Score: 0.82
# Word: well
#   Synonym: easily, Similarity Score: 0.97
#   Synonym: intimately, Similarity Score: 0.97
#   Synonym: good, Similarity Score: 0.97
#   Synonym: comfortably, Similarity Score: 0.96
#   Synonym: substantially, Similarity Score: 0.96
# Word: know
#   Synonym: recognize, Similarity Score: 0.98
#   Synonym: acknowledge, Similarity Score: 0.97
#   Synonym: recognise, Similarity Score: 0.95
#   Synonym: bang, Similarity Score: 0.95
#   Synonym: get it on, Similarity Score: 0.94
# Word: say
#   Synonym: tell, Similarity Score: 0.98
#   Synonym: read, Similarity Score: 0.98
#   Synonym: enjoin, Similarity Score: 0.97
#   Synonym: sound out, Similarity Score: 0.97
#   Synonym: order, Similarity Score: 0.96
# Word: bird
#   Synonym: doll, Similarity Score: 0.96
#   Synonym: shuttlecock, Similarity Score: 0.96
#   Synonym: chick, Similarity Score: 0.96
#   Synonym: shuttle, Similarity Score: 0.96
#   Synonym: hiss, Similarity Score: 0.96
# Word: catch
#   Synonym: trance, Similarity Score: 0.99
#   Synonym: hitch, Similarity Score: 0.99
#   Synonym: get, Similarity Score: 0.99
#   Synonym: see, Similarity Score: 0.98
#   Synonym: collar, Similarity Score: 0.98
# Word: worm
#   Synonym: twist, Similarity Score: 0.99
#   Synonym: louse, Similarity Score: 0.98
#   Synonym: insect, Similarity Score: 0.95
#   Synonym: squirm, Similarity Score: 0.95
#   Synonym: writhe, Similarity Score: 0.93
# Word: could
# Word: right
#   Synonym: flop, Similarity Score: 0.97
#   Synonym: proper, Similarity Score: 0.97
#   Synonym: right on, Similarity Score: 0.97
#   Synonym: properly, Similarity Score: 0.97
#   Synonym: correctly, Similarity Score: 0.97
# Word: maybe
#   Synonym: perhaps, Similarity Score: 0.99
#   Synonym: possibly, Similarity Score: 0.97
#   Synonym: mayhap, Similarity Score: 0.92
#   Synonym: peradventure, Similarity Score: 0.92
#   Synonym: perchance, Similarity Score: 0.91
# Word: try
#   Synonym: effort, Similarity Score: 0.97
#   Synonym: try on, Similarity Score: 0.97
#   Synonym: stress, Similarity Score: 0.97
#   Synonym: attempt, Similarity Score: 0.96
#   Synonym: test, Similarity Score: 0.96
# Word: go
#   Synonym: get going, Similarity Score: 0.97
#   Synonym: belong, Similarity Score: 0.97
#   Synonym: spell, Similarity Score: 0.96
#   Synonym: move, Similarity Score: 0.96
#   Synonym: get, Similarity Score: 0.96
# Word: bed
#   Synonym: screw, Similarity Score: 0.95
#   Synonym: love, Similarity Score: 0.95
#   Synonym: bang, Similarity Score: 0.95
#   Synonym: fuck, Similarity Score: 0.95
#   Synonym: layer, Similarity Score: 0.94
# Word: little
#   Synonym: slight, Similarity Score: 0.98
#   Synonym: petty, Similarity Score: 0.97
#   Synonym: minuscule, Similarity Score: 0.96
#   Synonym: footling, Similarity Score: 0.96
#   Synonym: niggling, Similarity Score: 0.95
# Word: earlier
#   Synonym: originally, Similarity Score: 0.98
#   Synonym: early, Similarity Score: 0.98
#   Synonym: other, Similarity Score: 0.98
#   Synonym: earliest, Similarity Score: 0.98
#   Synonym: before, Similarity Score: 0.97
# Word: tonight
#   Synonym: this evening, Similarity Score: 0.95
#   Synonym: this night, Similarity Score: 0.95
